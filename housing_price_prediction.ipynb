# %% [markdown]
# # Model solution file for week 3 assignment ML101

# %% [markdown]
# ## Introduction
#
# A huge step is always buying a new house. Is it the environment? Is it the general calibre of the house? Is it the size, perhaps? Could it eventually be resold for a profit? Economic growth is crucial since housing demand is frequently seen to be income-elastic, increasing household incomes. Here, we'll utilise machine learning to make data-based predictions about housing prices.
#
# Making a decision about which features should be given priority is undoubtedly tough. In the modern era, machine learning enables an entrepreneur to estimate the house price with the greatest degree of market trend accuracy and to develop a model of the historical dataset on "what happened and why" to predict "what is going to happen."
#
# The project aims to conduct extensive data analysis and the implementation of various machine learning techniques in Python in order to create the best model with the most important features of a house in terms of both business value and realistic perspective. The dataset contains 11 different variables for 532 different houses.
#
# ### Aim:
# - Performing necessary feature engineering step to clean clean and modify the data.
# - Identifying important features that may play important role to predict house price.
# - Predicitng house price using a machine learning model

# %%
# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
HP_raw = pd.read_csv('House_price.csv') # reading dataset
HP = HP_raw.copy() # creating a new copy

# %%
HP.head() # exploring first five variables to identify anamolies in the data
# Out:
#       h_price    area no_bedrooms no_bathrooms  total_stories mainroad_loc  \
# 0  13300000.0  7420.0     4 rooms   2 bathroom            3.0          yes
# 1  12250000.0  8960.0     4 rooms   4 bathroom            4.0          yes
# 2  12250000.0  9960.0     3 rooms   2 bathroom            2.0          yes
# 3  12215000.0  7500.0     4 rooms   2 bathroom            2.0          yes
# 4  11410000.0     NaN     4 rooms   1 bathroom            2.0          yes
#
#   guestroom hotwater airconditioner  parking furnishingstatus
# 0        no       no            yes      2.0        furnished
# 1        no       no            yes      3.0        furnished
# 2        no       no             no      2.0   semi-furnished
# 3        no       no            yes      3.0        furnished
# 4       yes       no            yes      2.0        furnished

# %% [markdown]
# - There are missing values present in few columns
# - no_bedrooms and no_bathrooms need to be performed well.

# %%
HP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   h_price           530 non-null    float64
#  1   area              516 non-null    float64
#  2   no_bedrooms       531 non-null    object
#  3   no_bathrooms      531 non-null    object
#  4   total_stories     530 non-null    float64
#  5   mainroad_loc      530 non-null    object
#  6   guestroom         530 non-null    object
#  7   hotwater          531 non-null    object
#  8   airconditioner    530 non-null    object
#  9   parking           531 non-null    float64
#  10  furnishingstatus  530 non-null    object
# dtypes: float64(4), object(7)
# memory usage: 45.8+ KB

# %%
HP.shape # Rechecking the number of observations and variables in the dataset
# Out:
# (532, 11)

# %%
HP.describe(include = 'all')
# Out:
#              h_price          area no_bedrooms no_bathrooms  total_stories  \
# count   5.300000e+02    516.000000         531          531     530.000000
# unique           NaN           NaN           6            4            NaN
# top              NaN           NaN     3 rooms   1 bathroom            NaN
# freq             NaN           NaN         290          392            NaN
# mean    4.780457e+06   5173.277132         NaN          NaN       1.800000
# std     1.871737e+06   2196.618447         NaN          NaN       0.863895
# min     1.750000e+06   1650.000000         NaN          NaN       1.000000
# 25%     3.465000e+06   3596.000000         NaN          NaN       1.000000
# 50%     4.340000e+06   4600.000000         NaN          NaN       2.000000
# 75%     5.766250e+06   6405.000000         NaN          NaN       2.000000
# max     1.330000e+07  16200.000000         NaN          NaN       4.000000
#
#        mainroad_loc guestroom hotwater airconditioner     parking  \
# count           530       530      531            530  531.000000
# unique            2         2        2              2         NaN
# top             yes        no       no             no         NaN
# freq            455       435      507            361         NaN
# mean            NaN       NaN      NaN            NaN    0.691149
# std             NaN       NaN      NaN            NaN    0.859298
# min             NaN       NaN      NaN            NaN    0.000000
# 25%             NaN       NaN      NaN            NaN    0.000000
# 50%             NaN       NaN      NaN            NaN    0.000000
# 75%             NaN       NaN      NaN            NaN    1.000000
# max             NaN       NaN      NaN            NaN    3.000000
#
#        furnishingstatus
# count               530
# unique                3
# top      semi-furnished
# freq                223
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN

# %%
HP.columns
# Out:
# Index(['h_price', 'area', 'no_bedrooms', 'no_bathrooms', 'total_stories',
#        'mainroad_loc', 'guestroom', 'hotwater', 'airconditioner', 'parking',
#        'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ### Dealing with missing values

# %%
HP.isnull().sum() # checking total number of missing values in each column
# Out:
# h_price              2
# area                16
# no_bedrooms          1
# no_bathrooms         1
# total_stories        2
# mainroad_loc         2
# guestroom            2
# hotwater             1
# airconditioner       2
# parking              1
# furnishingstatus     2
# dtype: int64

# %%
# checking if one observation has missing values more than 1
Missing_I = HP.isnull().sum(axis = 1)
Missing_I = Missing_I[Missing_I > 1]
Missing_I
# Out:
# 90     7
# 121    7
# dtype: int64

# %%
# exploring all rows and columns
pd.options.display.max_columns = None
pd.options.display.max_rows = None
display(HP)
# Out:
#         h_price     area no_bedrooms no_bathrooms  total_stories mainroad_loc  \
# 0    13300000.0   7420.0     4 rooms   2 bathroom            3.0          yes
# 1    12250000.0   8960.0     4 rooms   4 bathroom            4.0          yes
# 2    12250000.0   9960.0     3 rooms   2 bathroom            2.0          yes
# 3    12215000.0   7500.0     4 rooms   2 bathroom            2.0          yes
# 4    11410000.0      NaN     4 rooms   1 bathroom            2.0          yes
# 5    10850000.0   7500.0     3 rooms   3 bathroom            1.0          yes
# 6    10150000.0   8580.0     4 rooms   3 bathroom            4.0          yes
# 7    10150000.0  16200.0     5 rooms   3 bathroom            2.0          yes
# 8     9870000.0   8100.0     4 rooms   1 bathroom            2.0          yes
# 9     9800000.0   5750.0     3 rooms   2 bathroom            4.0          yes
# 10    9800000.0  13200.0     3 rooms   1 bathroom            2.0          yes
# 11    9681000.0   6000.0     4 rooms   3 bathroom            2.0          yes
# 12    9310000.0   6550.0     4 rooms   2 bathroom            2.0          yes
# 13    9240000.0   3500.0     4 rooms   2 bathroom            2.0          yes
# 14    9240000.0   7800.0     3 rooms   2 bathroom            2.0          yes
# 15    9100000.0   6000.0     4 rooms   1 bathroom            2.0          yes
# 16    9100000.0   6600.0     4 rooms   2 bathroom            2.0          yes
# 17    8960000.0   8500.0     3 rooms   2 bathroom            4.0          yes
# 18    8890000.0   4600.0     3 rooms   2 bathroom            2.0          yes
# 63    7000000.0  11175.0     3 rooms   1 bathroom            1.0          yes
# 64    6930000.0   8880.0     3 rooms   2 bathroom            2.0          yes
# 65    6930000.0  13200.0     2 rooms   1 bathroom            1.0          yes
# 66    6860000.0   6000.0     3 rooms   1 bathroom            1.0          yes
# 67    6790000.0  12090.0     4 rooms   2 bathroom            2.0          yes
# 68    6790000.0   4000.0     3 rooms   2 bathroom            2.0          yes
# 69    6755000.0   6000.0     4 rooms   2 bathroom            4.0          yes
# 70    6720000.0   5020.0     3 rooms   1 bathroom            4.0          yes
# 71    6685000.0   6600.0     2 rooms   2 bathroom            4.0          yes
# 72    6650000.0   4040.0     3 rooms   1 bathroom            2.0          yes
# 73    6650000.0   4260.0     4 rooms   2 bathroom            2.0          yes
# 74    6650000.0   6420.0     3 rooms   2 bathroom            3.0          yes
# 75    6650000.0   6500.0     3 rooms   2 bathroom            3.0          yes
# 76    6650000.0   5700.0     3 rooms   1 bathroom            1.0          yes
# 77    6650000.0   6000.0     3 rooms   2 bathroom            3.0          yes
# 78    6629000.0   6000.0     3 rooms   1 bathroom            2.0          yes
# 79    6615000.0   4000.0     3 rooms   2 bathroom            2.0          yes
# 80    6615000.0  10500.0     3 rooms   2 bathroom            1.0          yes
# 81    6580000.0   6000.0     3 rooms   2 bathroom            4.0          yes
# 82    6510000.0   3760.0     3 rooms   1 bathroom            2.0          yes
# 83    6510000.0   8250.0     3 rooms   2 bathroom            3.0          yes
# 84    6510000.0   6670.0     3 rooms   1 bathroom            3.0          yes
# 85    6475000.0   3960.0     3 rooms   1 bathroom            1.0          yes
# 86    6475000.0   7410.0     3 rooms   1 bathroom            1.0          yes
# 87    6440000.0   8580.0     5 rooms   3 bathroom            2.0          yes
# 88    6440000.0   5000.0     3 rooms   1 bathroom            2.0          yes
# 89    6419000.0   6750.0     2 rooms   1 bathroom            1.0          yes
# 90    6405000.0   4800.0         NaN          NaN            NaN          NaN
# 91    6300000.0   7200.0     3 rooms   2 bathroom            1.0          yes
# 92    6300000.0   6000.0     4 rooms   2 bathroom            4.0          yes
# 93    6300000.0   4100.0     3 rooms   2 bathroom            3.0          yes
# 94    6300000.0   9000.0     3 rooms   1 bathroom            1.0          yes
# 95    6300000.0   6400.0     3 rooms   1 bathroom            1.0          yes
# 96    6293000.0   6600.0     3 rooms   2 bathroom            3.0          yes
# 97    6265000.0   6000.0     4 rooms   1 bathroom            3.0          yes
# 98    6230000.0   6600.0     3 rooms   2 bathroom            1.0          yes
# 99    6230000.0   5500.0     3 rooms   1 bathroom            3.0          yes
# 100   6195000.0   5500.0     3 rooms   2 bathroom            4.0          yes
# 101   6195000.0   6350.0     3 rooms   2 bathroom            3.0          yes
# 102   6195000.0   5500.0     3 rooms   2 bathroom            1.0          yes
# 103   6160000.0      NaN     3 rooms   1 bathroom            4.0          yes
# 104   6160000.0   5450.0     4 rooms   2 bathroom            1.0          yes
# 105   6107500.0   3240.0     4 rooms   1 bathroom            3.0          yes
# 106   6090000.0   6615.0     4 rooms   2 bathroom            2.0          yes
# 107   6090000.0   6600.0     3 rooms   1 bathroom            1.0          yes
# 108   6090000.0   8372.0     3 rooms   1 bathroom            3.0          yes
# 109   6083000.0   4300.0     6 rooms   2 bathroom            2.0          yes
# 110   6083000.0   9620.0     3 rooms   1 bathroom            1.0          yes
# 111   6020000.0   6800.0     2 rooms   1 bathroom            1.0          yes
# 112   6020000.0   8000.0     3 rooms   1 bathroom            1.0          yes
# 113   6020000.0   6900.0     3 rooms   2 bathroom            1.0          yes
# 114   5950000.0   3700.0     4 rooms   1 bathroom            2.0          yes
# 115   5950000.0   6420.0     3 rooms   1 bathroom            1.0          yes
# 116   5950000.0   7020.0     3 rooms   1 bathroom            1.0          yes
# 117   5950000.0   6540.0     3 rooms   1 bathroom            1.0          yes
# 118   5950000.0   7231.0     3 rooms   1 bathroom            2.0          yes
# 119   5950000.0   6254.0     4 rooms   2 bathroom            1.0          yes
# 120   5950000.0   7320.0     4 rooms   2 bathroom            2.0          yes
# 121   5950000.0   6525.0     3 rooms   2 bathroom            NaN          NaN
# 122   5943000.0  15600.0     3 rooms   1 bathroom            1.0          yes
# 123   5880000.0   7160.0     3 rooms   1 bathroom            1.0          yes
# 124   5880000.0   6500.0     3 rooms   2 bathroom            3.0          yes
# 125   5873000.0   5500.0     3 rooms   1 bathroom            3.0          yes
# 126   5873000.0  11460.0     3 rooms   1 bathroom            3.0          yes
# 127   5866000.0      NaN     3 rooms   1 bathroom            1.0          yes
# 128   5810000.0   5828.0     4 rooms   1 bathroom            4.0          yes
# 129   5810000.0   5200.0     3 rooms   1 bathroom            3.0          yes
# 130   5810000.0   4800.0     3 rooms   1 bathroom            3.0          yes
# 131   5803000.0   7000.0     3 rooms   1 bathroom            1.0          yes
# 132   5775000.0   6000.0     3 rooms   2 bathroom            4.0          yes
# 133   5740000.0   5400.0     4 rooms   2 bathroom            2.0          yes
# 134   5740000.0   4640.0     4 rooms   1 bathroom            2.0          yes
# 135   5740000.0   5000.0     3 rooms   1 bathroom            3.0          yes
# 136   5740000.0   6360.0     3 rooms   1 bathroom            1.0          yes
# 137   5740000.0   5800.0     3 rooms   2 bathroom            4.0          yes
# 138   5652500.0   6660.0     4 rooms   2 bathroom            2.0          yes
# 139   5600000.0  10500.0     4 rooms   2 bathroom            2.0          yes
# 140   5600000.0   4800.0     5 rooms   2 bathroom            3.0           no
# 141   5600000.0   4700.0     4 rooms   1 bathroom            2.0          yes
# 142   5600000.0   5000.0     3 rooms   1 bathroom            4.0          yes
# 143   5600000.0  10500.0     2 rooms   1 bathroom            1.0          yes
# 144   5600000.0   6360.0     3 rooms   1 bathroom            3.0          yes
# 145   5600000.0   6600.0     4 rooms   2 bathroom            1.0          yes
# 146   5600000.0   5136.0     3 rooms   1 bathroom            2.0          yes
# 147   5565000.0   4400.0     4 rooms   1 bathroom            2.0          yes
# 148   5565000.0   5400.0     5 rooms   1 bathroom            2.0          yes
# 149   5530000.0      NaN     3 rooms   3 bathroom            2.0          yes
# 502   2485000.0   3000.0     3 rooms   1 bathroom            2.0           no
# 503   2450000.0   3210.0     3 rooms   1 bathroom            2.0          yes
# 504   2450000.0   3240.0     2 rooms   1 bathroom            1.0           no
# 505   2450000.0   3000.0     2 rooms   1 bathroom            1.0          yes
# 506   2450000.0   3500.0     2 rooms   1 bathroom            1.0          yes
# 507   2450000.0   4840.0     2 rooms   1 bathroom            2.0          yes
# 508   2450000.0   7700.0     2 rooms   1 bathroom            1.0          yes
# 509   2408000.0   3635.0     2 rooms   1 bathroom            1.0           no
# 510   2380000.0   2475.0     3 rooms   1 bathroom            2.0          yes
# 511   2380000.0   2787.0     4 rooms   2 bathroom            2.0          yes
# 512   2380000.0   3264.0     2 rooms   1 bathroom            1.0          yes
# 513   2345000.0   3640.0     2 rooms   1 bathroom            1.0          yes
# 514   2310000.0   3180.0     2 rooms   1 bathroom            1.0          yes
# 515   2275000.0   1836.0     2 rooms   1 bathroom            1.0           no
# 516   2275000.0   3970.0     1 rooms   1 bathroom            1.0           no
# 517   2275000.0   3970.0     3 rooms   1 bathroom            2.0          yes
# 518   2240000.0   1950.0     3 rooms   1 bathroom            1.0           no
# 519   2233000.0   5300.0     3 rooms   1 bathroom            1.0           no
# 520   2135000.0   3000.0     2 rooms   1 bathroom            1.0           no
# 521   2100000.0   2400.0     3 rooms   1 bathroom            2.0          yes
# 522   2100000.0   3000.0     4 rooms   1 bathroom            2.0          yes
# 523   2100000.0   3360.0     2 rooms   1 bathroom            1.0          yes
# 524   1960000.0   3420.0     5 rooms   1 bathroom            2.0           no
# 525   1890000.0   1700.0     3 rooms   1 bathroom            2.0          yes
# 526   1890000.0   3649.0     2 rooms   1 bathroom            1.0          yes
# 527   1855000.0   2990.0     2 rooms   1 bathroom            1.0           no
# 528   1820000.0      NaN     2 rooms   1 bathroom            1.0          yes
# 529   1767150.0   2400.0     3 rooms   1 bathroom            1.0           no
# 530   1750000.0   3620.0     2 rooms   1 bathroom            1.0          yes
# 531   1750000.0   3850.0     3 rooms   1 bathroom            2.0          yes
#
#     guestroom hotwater airconditioner  parking furnishingstatus
# 0          no       no            yes      2.0        furnished
# 1          no       no            yes      3.0        furnished
# 2          no       no             no      2.0   semi-furnished
# 3          no       no            yes      3.0        furnished
# 4         yes       no            yes      2.0        furnished
# 5          no       no            yes      2.0   semi-furnished
# 6          no       no            yes      2.0   semi-furnished
# 7          no       no             no      0.0      unfurnished
# 8         yes       no            yes      2.0        furnished
# 9         yes       no            yes      1.0      unfurnished
# 10         no       no            yes      2.0        furnished
# 11        yes      yes             no      2.0   semi-furnished
# 12         no       no            yes      1.0   semi-furnished
# 13         no      yes             no      2.0        furnished
# 14         no       no             no      0.0   semi-furnished
# 15         no       no             no      2.0   semi-furnished
# 16        yes       no            yes      1.0      unfurnished
# 17         no       no            yes      2.0        furnished
# 18        yes       no            yes      2.0        furnished
# 19         no       no            yes      1.0   semi-furnished
# 20         no      yes             no      2.0   semi-furnished
# 21        yes       no            yes      2.0      unfurnished
# 22        yes       no            yes      1.0        furnished
# 23        yes       no            yes      1.0        furnished
# 24         no       no            yes      2.0        furnished
# 25        yes       no            yes      2.0        furnished
# 26        yes       no            yes      0.0   semi-furnished
# 27         no       no             no      1.0   semi-furnished
# 28         no       no            yes      1.0   semi-furnished
# 29         no       no            yes      2.0      unfurnished
# 30         no       no            yes      2.0   semi-furnished
# 31         no       no            yes      1.0        furnished
# 32        yes       no             no      1.0      unfurnished
# 33        yes       no            yes      1.0        furnished
# 34         no       no            yes      2.0        furnished
# 35         no      yes             no      1.0        furnished
# 36         no       no            yes      2.0        furnished
# 37        yes       no            yes      2.0      unfurnished
# 38         no       no            yes      1.0   semi-furnished
# 39         no       no            yes      0.0        furnished
# 40         no       no            yes      0.0        furnished
# 41         no       no            yes      2.0      unfurnished
# 42         no       no             no      2.0   semi-furnished
# 43         no       no            yes      1.0        furnished
# 44         no       no            yes      0.0   semi-furnished
# 45         no       no            yes      1.0        furnished
# 46         no       no            yes      3.0        furnished
# 47         no       no             no      1.0      unfurnished
# 48        yes       no            yes      0.0   semi-furnished
# 49         no       no             no      1.0      unfurnished
# 50         no       no            yes      1.0      unfurnished
# 51        yes       no            yes      1.0        furnished
# 52         no       no            yes      2.0   semi-furnished
# 53        yes       no            yes      1.0   semi-furnished
# 54         no       no            yes      1.0      unfurnished
# 55         no       no             no      1.0   semi-furnished
# 56        yes       no            yes      1.0        furnished
# 57        yes       no            yes      1.0   semi-furnished
# 58        yes       no            yes      1.0        furnished
# 59        yes       no             no      1.0   semi-furnished
# 60         no       no            yes      1.0   semi-furnished
# 61         no       no            yes      1.0        furnished
# 62         no       no            yes      2.0        furnished
# 63         no       no            yes      1.0        furnished
# 64         no       no            yes      1.0        furnished
# 65         no      yes             no      1.0        furnished
# 66         no       no            yes      1.0        furnished
# 67         no       no             no      2.0        furnished
# 68         no       no            yes      0.0   semi-furnished
# 69         no       no            yes      0.0      unfurnished
# 70         no       no            yes      0.0      unfurnished
# 71         no       no             no      0.0        furnished
# ...
# 290        no       no            yes      1.0   semi-furnished
# 291        no       no             no      0.0      unfurnished
# 292        no      yes             no      2.0   semi-furnished
# 293        no       no             no      3.0        furnished
# 294        no       no             no      0.0   semi-furnished
# 295        no       no             no      0.0   semi-furnished
# 296        no       no             no      1.0      unfurnished
# 297        no       no             no      0.0        furnished
# 298        no       no             no      3.0   semi-furnished
# 299        no       no             no      1.0   semi-furnished
# 300        no       no             no      1.0   semi-furnished
# 301        no       no             no      2.0   semi-furnished
# 302        no       no             no      1.0   semi-furnished
# 303        no       no            yes      0.0   semi-furnished
# 304        no       no             no      1.0   semi-furnished
# 305        no       no            yes      0.0        furnished
# 306        no       no             no      0.0   semi-furnished
# 307        no       no             no      1.0   semi-furnished
# 308        no       no            yes      0.0   semi-furnished
# 309        no       no             no      1.0      unfurnished
# 310        no       no             no      2.0      unfurnished
# 311        no       no             no      0.0   semi-furnished
# 312        no       no            yes      2.0   semi-furnished
# 313        no       no             no      2.0        furnished
# 314        no      yes             no      2.0   semi-furnished
# 315        no       no            yes      1.0        furnished
# 316        no       no             no      3.0   semi-furnished
# 317        no       no            yes      0.0   semi-furnished
# 318        no       no            yes      0.0   semi-furnished
# 319        no       no             no      0.0      unfurnished
# 320        no       no            yes      1.0   semi-furnished
# 321        no       no            yes      0.0   semi-furnished
# 322        no       no             no      0.0        furnished
# 323       yes       no             no      0.0      unfurnished
# 324       yes       no             no      3.0        furnished
# 325       yes       no             no      0.0   semi-furnished
# 326        no       no             no      0.0   semi-furnished
# 327        no      yes             no      1.0        furnished
# 328        no       no            yes      2.0        furnished
# 329        no       no            yes      2.0   semi-furnished
# 330        no       no             no      0.0      unfurnished
# 331       yes       no             no      0.0   semi-furnished
# 332        no       no             no      0.0        furnished
# 333        no       no             no      0.0   semi-furnished
# 334        no       no             no      2.0   semi-furnished
# 335        no       no             no      0.0   semi-furnished
# 336        no       no             no      0.0   semi-furnished
# 337        no       no             no      0.0   semi-furnished
# 338       yes       no             no      0.0   semi-furnished
# 339        no       no             no      0.0      unfurnished
# 340        no       no             no      0.0   semi-furnished
# 341        no       no             no      0.0   semi-furnished
# 342        no      yes             no      1.0   semi-furnished
# 343        no       no             no      0.0   semi-furnished
# 344        no       no             no      2.0      unfurnished
# 345        no       no             no      0.0        furnished
# 346        no       no             no      1.0        furnished
# 347        no       no             no      2.0        furnished
# 348        no       no            yes      1.0        furnished
# 349        no       no             no      1.0        furnished
# 350        no       no             no      0.0   semi-furnished
# 351        no       no             no      1.0      unfurnished
# 352        no       no             no      0.0   semi-furnished
# 353        no       no             no      0.0   semi-furnished
# 354        no       no             no      0.0        furnished
# 355        no      yes             no      0.0   semi-furnished
# 356        no      yes             no      0.0   semi-furnished
# 357        no       no             no      0.0        furnished
# 358        no       no             no      0.0        furnished
# 359        no       no            yes      0.0      unfurnished
# 360        no       no             no      0.0   semi-furnished
# 361        no       no             no      0.0        furnished
# 362        no       no            yes      2.0   semi-furnished
# 363        no       no             no      0.0   semi-furnished
# 364        no       no             no      0.0   semi-furnished
# 365        no       no            yes      0.0        furnished
# 366        no       no             no      0.0   semi-furnished
# 367       yes       no             no      0.0      unfurnished
# 368        no       no             no      2.0   semi-furnished
# 369        no       no             no      0.0      unfurnished
# 370        no      yes            yes      0.0   semi-furnished
# 371        no       no             no      2.0      unfurnished
# 372        no       no             no      0.0   semi-furnished
# 373        no       no             no      0.0   semi-furnished
# 374        no       no             no      0.0        furnished
# 375        no       no             no      2.0        furnished
# 376        no       no             no      0.0      unfurnished
# 377        no       no             no      2.0      unfurnished
# 378        no       no            yes      0.0   semi-furnished
# 379        no       no             no      0.0      unfurnished
# 380        no       no             no      0.0   semi-furnished
# 381        no       no             no      0.0      unfurnished
# 382        no       no             no      0.0   semi-furnished
# 383        no       no             no      0.0   semi-furnished
# 384        no       no             no      0.0      unfurnished
# 385        no       no            yes      0.0      unfurnished
# 386        no       no             no      1.0      unfurnished
# 387        no       no             no      1.0   semi-furnished
# 388        no       no             no      1.0        furnished
# 389        no       no             no      1.0      unfurnished
# 390        no       no             no      1.0   semi-furnished
# 391        no       no             no      1.0      unfurnished
# 392        no       no             no      3.0      unfurnished
# 393        no       no             no      0.0      unfurnished
# 394        no       no             no      0.0      unfurnished
# 395        no       no             no      0.0      unfurnished
# 396        no       no             no      0.0      unfurnished
# 397        no       no             no      1.0      unfurnished
# 398        no       no             no      0.0        furnished
# 399        no       no             no      0.0      unfurnished
# 400        no       no             no      2.0      unfurnished
# 401        no       no             no      0.0      unfurnished
# 402        no       no             no      0.0        furnished
# 403        no       no             no      0.0      unfurnished
# 404        no       no             no      0.0      unfurnished
# 405        no       no             no      0.0      unfurnished
# 406       yes       no            yes      1.0        furnished
# 407        no       no             no      2.0      unfurnished
# 408        no       no             no      0.0        furnished
# 409        no       no            yes      2.0      unfurnished
# 410        no       no             no      0.0   semi-furnished
# 411        no       no             no      0.0      unfurnished
# 412        no       no             no      0.0      unfurnished
# 413        no       no            yes      0.0      unfurnished
# 414        no       no             no      0.0      unfurnished
# 415        no       no             no      0.0   semi-furnished
# 416        no       no             no      2.0        furnished
# 417        no       no             no      0.0        furnished
# 418        no       no             no      1.0      unfurnished
# 419        no       no             no      0.0      unfurnished
# 420        no       no            yes      0.0      unfurnished
# 421        no       no            yes      0.0      unfurnished
# 422       yes       no             no      0.0        furnished
# 423        no       no             no      1.0   semi-furnished
# 424        no       no             no      0.0   semi-furnished
# 425        no       no             no      0.0      unfurnished
# 426        no       no             no      0.0        furnished
# 427        no       no             no      1.0      unfurnished
# 428        no       no             no      0.0   semi-furnished
# 429        no       no             no      0.0      unfurnished
# 430        no       no             no      0.0      unfurnished
# 431        no       no             no      0.0      unfurnished
# 432        no       no            yes      1.0      unfurnished
# 433        no       no             no      1.0      unfurnished
# 434        no       no             no      0.0        furnished
# 435        no       no             no      0.0        furnished
# 436       yes       no             no      1.0      unfurnished
# 437        no       no             no      0.0   semi-furnished
# 438        no       no             no      2.0   semi-furnished
# 439        no       no             no      0.0      unfurnished
# 440        no       no             no      0.0   semi-furnished
# 441        no       no             no      0.0   semi-furnished
# 442        no       no             no      2.0   semi-furnished
# 443        no       no             no      1.0      unfurnished
# 444        no       no            yes      0.0      unfurnished
# 445        no       no             no      0.0      unfurnished
# 446        no       no             no      0.0   semi-furnished
# 447        no       no            yes      0.0      unfurnished
# 448        no       no             no      0.0      unfurnished
# 449        no       no             no      0.0      unfurnished
# 450        no       no             no      1.0      unfurnished
# 451        no       no            yes      0.0      unfurnished
# 452        no       no             no      0.0   semi-furnished
# 453       yes       no             no      0.0      unfurnished
# 454        no      yes             no      1.0   semi-furnished
# 455        no       no             no      0.0      unfurnished
# 456        no       no             no      0.0   semi-furnished
# 457        no       no             no      2.0   semi-furnished
# 458        no       no             no      0.0   semi-furnished
# 459        no       no             no      0.0        furnished
# 460        no       no             no      0.0      unfurnished
# 461        no       no             no      0.0      unfurnished
# 462        no       no             no      0.0      unfurnished
# 463        no       no             no      1.0      unfurnished
# 464        no       no             no      0.0   semi-furnished
# 465        no       no             no      1.0      unfurnished
# 466        no       no             no      0.0      unfurnished
# 467        no       no             no      1.0      unfurnished
# 468        no       no             no      0.0      unfurnished
# 469        no       no             no      1.0   semi-furnished
# 470        no       no             no      0.0        furnished
# 471        no       no             no      0.0      unfurnished
# 472        no       no             no      0.0   semi-furnished
# 473        no       no             no      0.0      unfurnished
# 474        no       no             no      0.0      unfurnished
# 475        no       no             no      0.0   semi-furnished
# 476        no       no             no      0.0      unfurnished
# 477        no       no             no      0.0      unfurnished
# 478        no       no             no      1.0   semi-furnished
# 479        no      yes             no      1.0      unfurnished
# 480        no       no             no      1.0        furnished
# 481        no       no             no      1.0      unfurnished
# 482        no       no             no      0.0        furnished
# 483        no       no             no      0.0      unfurnished
# 484        no       no             no      1.0      unfurnished
# 485        no       no             no      0.0      unfurnished
# 486        no       no             no      0.0      unfurnished
# 487        no       no             no      0.0   semi-furnished
# 488       yes       no             no      0.0      unfurnished
# 489        no       no             no      0.0      unfurnished
# 490        no       no             no      0.0      unfurnished
# 491        no       no             no      1.0   semi-furnished
# 492        no       no             no      0.0   semi-furnished
# 493        no       no            yes      0.0      unfurnished
# 494        no       no            yes      0.0      unfurnished
# 495        no       no             no      0.0      unfurnished
# 496        no       no             no      0.0      unfurnished
# 497        no       no             no      0.0      unfurnished
# 498        no       no             no      0.0      unfurnished
# 499        no       no             no      0.0      unfurnished
# 500        no       no             no      0.0        furnished
# 501        no       no             no      0.0      unfurnished
# 502        no       no             no      0.0   semi-furnished
# 503        no       no             no      0.0      unfurnished
# 504       yes       no             no      1.0      unfurnished
# 505        no       no             no      1.0      unfurnished
# 506       yes       no             no      0.0      unfurnished
# 507        no       no             no      0.0      unfurnished
# 508        no       no             no      0.0      unfurnished
# 509        no       no             no      0.0      unfurnished
# 510        no       no             no      0.0        furnished
# 511        no       no             no      0.0        furnished
# 512        no       no             no      0.0      unfurnished
# 513        no       no             no      0.0      unfurnished
# 514        no       no             no      0.0      unfurnished
# 515        no       no             no      0.0   semi-furnished
# 516        no       no             no      0.0      unfurnished
# 517        no       no             no      0.0      unfurnished
# 518        no      yes             no      0.0      unfurnished
# 519        no       no            yes      0.0      unfurnished
# 520        no       no             no      0.0      unfurnished
# 521        no       no             no      0.0      unfurnished
# 522        no       no             no      0.0      unfurnished
# 523        no       no             no      1.0      unfurnished
# 524        no       no             no      0.0      unfurnished
# 525        no       no             no      0.0      unfurnished
# 526        no       no             no      0.0      unfurnished
# 527        no       no             no      1.0      unfurnished
# 528        no       no             no      2.0      unfurnished
# 529        no       no             no      0.0   semi-furnished
# 530        no       no             no      0.0      unfurnished
# 531        no       no             no      0.0      unfurnished

# %%
# visualization of missing values
import missingno as msno
msno.matrix(HP)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Apart from area column, rest other columns have very less missing values.
# - Either we can remove them or replace with something like mean or median too.
# - Label data (house price) also has some missing values. We have to remove it as it is labelled column.
# - There are 7 missing values in index 90 and 121. It is also very clear from missing plots. Hence, they have to be romoved.

# %%
# Dropping the 2 rows with null values for all variables
HP.drop(HP[HP['total_stories'].isnull()].index,axis=0, inplace=True)

# %%
# Dropping the null values from target variable
HP.drop(HP[HP['h_price'].isnull()].index,axis=0, inplace=True)

# %%
HP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528 entries, 0 to 531
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   h_price           528 non-null    float64
#  1   area              512 non-null    float64
#  2   no_bedrooms       528 non-null    object
#  3   no_bathrooms      528 non-null    object
#  4   total_stories     528 non-null    float64
#  5   mainroad_loc      528 non-null    object
#  6   guestroom         528 non-null    object
#  7   hotwater          528 non-null    object
#  8   airconditioner    528 non-null    object
#  9   parking           528 non-null    float64
#  10  furnishingstatus  528 non-null    object
# dtypes: float64(4), object(7)
# memory usage: 49.5+ KB

# %% [markdown]
# ### Before dealing with missing values we have to encode all categorical data

# %%
# Ordinal encoding for number of bedroom, bathroom and furnishing status
# we can also use regular expression too
from sklearn.preprocessing import OrdinalEncoder
Or_enc = OrdinalEncoder()
HP[["no_bedrooms","no_bathrooms", "furnishingstatus"]] = Or_enc.fit_transform(HP[["no_bedrooms","no_bathrooms", "furnishingstatus"]])

# %%
# label encoding for rest categorical variable
from sklearn.preprocessing import LabelEncoder

for col in ["mainroad_loc","guestroom", "hotwater", "airconditioner"]:
    HP[col] = LabelEncoder().fit_transform(HP[col])

# %%
HP.head()
# Out:
#       h_price    area  no_bedrooms  no_bathrooms  total_stories  mainroad_loc  \
# 0  13300000.0  7420.0          3.0           1.0            3.0             1
# 1  12250000.0  8960.0          3.0           3.0            4.0             1
# 2  12250000.0  9960.0          2.0           1.0            2.0             1
# 3  12215000.0  7500.0          3.0           1.0            2.0             1
# 4  11410000.0     NaN          3.0           0.0            2.0             1
#
#    guestroom  hotwater  airconditioner  parking  furnishingstatus
# 0          0         0               1      2.0               0.0
# 1          0         0               1      3.0               0.0
# 2          0         0               0      2.0               1.0
# 3          0         0               1      3.0               0.0
# 4          1         0               1      2.0               0.0

# %%
# To avoid data leakage from outcom variable splitting the data set
Independent = HP.drop('h_price',axis=1)
Independent.head()
# Out:
#      area  no_bedrooms  no_bathrooms  total_stories  mainroad_loc  guestroom  \
# 0  7420.0          3.0           1.0            3.0             1          0
# 1  8960.0          3.0           3.0            4.0             1          0
# 2  9960.0          2.0           1.0            2.0             1          0
# 3  7500.0          3.0           1.0            2.0             1          0
# 4     NaN          3.0           0.0            2.0             1          1
#
#    hotwater  airconditioner  parking  furnishingstatus
# 0         0               1      2.0               0.0
# 1         0               1      3.0               0.0
# 2         0               0      2.0               1.0
# 3         0               1      3.0               0.0
# 4         0               1      2.0               0.0

# %%
Dependent = HP['h_price'] # creating Y variable only
Dependent.head()
# Out:
# 0    13300000.0
# 1    12250000.0
# 2    12250000.0
# 3    12215000.0
# 4    11410000.0
# Name: h_price, dtype: float64

# %%
# Imputation using KNN
from fancyimpute import KNN
knn_imputer = KNN()
Independent_knn = Independent.copy(deep=True)
Independent_knn.iloc[:, :] = knn_imputer.fit_transform(Independent_knn)
# Out:
# Imputing row 1/528 with 0 missing, elapsed time: 0.043
# Imputing row 101/528 with 0 missing, elapsed time: 0.043
# Imputing row 201/528 with 0 missing, elapsed time: 0.043
# Imputing row 301/528 with 0 missing, elapsed time: 0.043
# Imputing row 401/528 with 0 missing, elapsed time: 0.043
# Imputing row 501/528 with 0 missing, elapsed time: 0.051

# %%
# Imputation using MICE
from fancyimpute import IterativeImputer
MICE_imputer = IterativeImputer()
Independent_MICE = Independent.copy(deep=True)
Independent_MICE.iloc[:, :] = MICE_imputer.fit_transform(Independent_MICE)

# %%
fig, ax =plt.subplots(1,3)
sns.histplot(HP['area'],bins=20, color="purple", ax=ax[0])
sns.histplot(Independent_knn['area'], color="red", bins=20, ax=ax[1])
sns.histplot(Independent_MICE['area'], color="green", bins=20, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='area', ylabel='Count'>

# %%
fig, ax =plt.subplots(1,3)
sns.boxplot(HP['area'], color="purple", ax=ax[0])
sns.boxplot(Independent_knn['area'], color="red", ax=ax[1])
sns.boxplot(Independent_MICE['area'], color="green", ax=ax[2])
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area'>

# %%
Independent_knn.describe() # using describe function to see if there is any discrepency in numerical measures
# Out:
#                area  no_bedrooms  no_bathrooms  total_stories  mainroad_loc  \
# count    528.000000   528.000000    528.000000     528.000000    528.000000
# mean    5162.840220     1.964015      0.284091       1.803030      0.857955
# std     2182.518656     0.739655      0.503095       0.864123      0.349428
# min     1650.000000     0.000000      0.000000       1.000000      0.000000
# 25%     3600.000000     1.000000      0.000000       1.000000      1.000000
# 50%     4580.000000     2.000000      0.000000       2.000000      1.000000
# 75%     6360.000000     2.000000      1.000000       2.000000      1.000000
# max    16200.000000     5.000000      3.000000       4.000000      1.000000
#
#         guestroom    hotwater  airconditioner     parking  furnishingstatus
# count  528.000000  528.000000      528.000000  528.000000        528.000000
# mean     0.179924    0.045455        0.320076    0.695076          1.077652
# std      0.384489    0.208496        0.466948    0.860152          0.756774
# min      0.000000    0.000000        0.000000    0.000000          0.000000
# 25%      0.000000    0.000000        0.000000    0.000000          0.750000
# 50%      0.000000    0.000000        0.000000    0.000000          1.000000
# 75%      0.000000    0.000000        1.000000    1.000000          2.000000
# max      1.000000    1.000000        1.000000    3.000000          2.000000

# %%
Independent_MICE.describe() # using describe function to see if there is any discrepency in numerical measures
# Out:
#                area  no_bedrooms  no_bathrooms  total_stories  mainroad_loc  \
# count    528.000000   528.000000    528.000000     528.000000    528.000000
# mean    5169.721163     1.964015      0.284091       1.803030      0.857955
# std     2173.611257     0.739655      0.503095       0.864123      0.349428
# min     1650.000000     0.000000      0.000000       1.000000      0.000000
# 25%     3600.000000     1.000000      0.000000       1.000000      1.000000
# 50%     4615.820057     2.000000      0.000000       2.000000      1.000000
# 75%     6360.000000     2.000000      1.000000       2.000000      1.000000
# max    16200.000000     5.000000      3.000000       4.000000      1.000000
#
#         guestroom    hotwater  airconditioner     parking  furnishingstatus
# count  528.000000  528.000000      528.000000  528.000000        528.000000
# mean     0.179924    0.045455        0.320076    0.695076          1.077652
# std      0.384489    0.208496        0.466948    0.860152          0.756774
# min      0.000000    0.000000        0.000000    0.000000          0.000000
# 25%      0.000000    0.000000        0.000000    0.000000          0.750000
# 50%      0.000000    0.000000        0.000000    0.000000          1.000000
# 75%      0.000000    0.000000        1.000000    1.000000          2.000000
# max      1.000000    1.000000        1.000000    3.000000          2.000000

# %% [markdown]
# - From overall exploration it seems that MICE and KNN both performed well
# - Hence, I will go ahead with KNN imputation

# %%
HP_miss = pd.concat([Independent_knn, Dependent], axis=1) # concatenating independent and dependent variable
HP_miss.head(10)
# Out:
#            area  no_bedrooms  no_bathrooms  total_stories  mainroad_loc  \
# 0   7420.000000          3.0           1.0            3.0           1.0
# 1   8960.000000          3.0           3.0            4.0           1.0
# 2   9960.000000          2.0           1.0            2.0           1.0
# 3   7500.000000          3.0           1.0            2.0           1.0
# 4   8099.945192          3.0           0.0            2.0           1.0
# 5   7500.000000          2.0           2.0            1.0           1.0
# 6   8580.000000          3.0           2.0            4.0           1.0
# 7  16200.000000          4.0           2.0            2.0           1.0
# 8   8100.000000          3.0           0.0            2.0           1.0
# 9   5750.000000          2.0           1.0            4.0           1.0
#
#    guestroom  hotwater  airconditioner  parking  furnishingstatus     h_price
# 0        0.0       0.0             1.0      2.0               0.0  13300000.0
# 1        0.0       0.0             1.0      3.0               0.0  12250000.0
# 2        0.0       0.0             0.0      2.0               1.0  12250000.0
# 3        0.0       0.0             1.0      3.0               0.0  12215000.0
# 4        1.0       0.0             1.0      2.0               0.0  11410000.0
# 5        0.0       0.0             1.0      2.0               1.0  10850000.0
# 6        0.0       0.0             1.0      2.0               1.0  10150000.0
# 7        0.0       0.0             0.0      0.0               2.0  10150000.0
# 8        1.0       0.0             1.0      2.0               0.0   9870000.0
# 9        1.0       0.0             1.0      1.0               2.0   9800000.0

# %% [markdown]
# ### Dealing with outliers

# %%
# Here I am using IQR to remove outliers. I have already checked Z score and did not work well
# IQR for price column
Q1 = HP_miss['h_price'].quantile(0.25)
Q3 = HP_miss['h_price'].quantile(0.75)
print(Q3, Q1)
IQR = Q3 - Q1
print(IQR)
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR
print(upper_bound)
print(lower_bound)
# Out:
# 5740000.0 3465000.0
# 2275000.0
# 9152500.0
# 52500.0

# %%
HP_miss_out = HP_miss[HP_miss.h_price < upper_bound]
HP_miss_out = HP_miss_out[HP_miss.h_price > lower_bound]
HP_miss_out.shape
# Out:
# C:\Users\sandy\AppData\Local\Temp/ipykernel_12748/1866707801.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HP_miss_out = HP_miss_out[HP_miss.h_price > lower_bound]
# (513, 11)

# %%
sns.histplot(HP_miss_out['h_price'])
# Out:
# <AxesSubplot:xlabel='h_price', ylabel='Count'>

# %%
# Here I am using IQR to remove outliers. I have already checked Z score and did not work well
# IQR for price column
Q1 = HP_miss_out['area'].quantile(0.25)
Q3 = HP_miss_out['area'].quantile(0.75)
print(Q3, Q1)
IQR = Q3 - Q1
print(IQR)
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR
print(upper_bound)
print(lower_bound)
# Out:
# 6321.0 3584.0
# 2737.0
# 10426.5
# -521.5

# %%
HP_miss_out = HP_miss_out[HP_miss.area < upper_bound]
HP_miss_out = HP_miss_out[HP_miss.area > lower_bound]
HP_miss_out.shape
# Out:
# C:\Users\sandy\AppData\Local\Temp/ipykernel_12748/3980939757.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HP_miss_out = HP_miss_out[HP_miss.area < upper_bound]
# C:\Users\sandy\AppData\Local\Temp/ipykernel_12748/3980939757.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HP_miss_out = HP_miss_out[HP_miss.area > lower_bound]
# (500, 11)

# %%
sns.histplot(HP_miss_out['area']) # examining distribution of area column
# Out:
# <AxesSubplot:xlabel='area', ylabel='Count'>

# %% [markdown]
# - Even after removing outliers price and area columns are skewed.
# - For linear regression, errors should be normally distributed. However, as per central limit theorem if sample size is more than 30 we are good to go.

# %%
# scatter plot between area and price
sns.scatterplot(HP_miss_out.h_price, HP_miss_out.area)
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='h_price', ylabel='area'>

# %%
data = pd.DataFrame(HP_miss_out) # checking correlation only between price and area
print(data.corr(method = 'spearman'))
# Out:
#                       area  no_bedrooms  no_bathrooms  total_stories  \
# area              1.000000     0.148777      0.195659       0.042915
# no_bedrooms       0.148777     1.000000      0.360151       0.510301
# no_bathrooms      0.195659     0.360151      1.000000       0.292542
# total_stories     0.042915     0.510301      0.292542       1.000000
# mainroad_loc      0.328205    -0.025744      0.027910       0.084053
# guestroom         0.251026     0.089055      0.156024       0.018469
# hotwater         -0.033229     0.014585      0.040439       0.051932
# airconditioner    0.295852     0.173915      0.209135       0.234156
# parking           0.334091     0.102540      0.131408      -0.008298
# furnishingstatus -0.155728    -0.133968     -0.161125      -0.101542
# h_price           0.572912     0.369470      0.453527       0.354870
#
#                   mainroad_loc  guestroom  hotwater  airconditioner   parking  \
# area                  0.328205   0.251026 -0.033229        0.295852  0.334091
# no_bedrooms          -0.025744   0.089055  0.014585        0.173915  0.102540
# no_bathrooms          0.027910   0.156024  0.040439        0.209135  0.131408
# total_stories         0.084053   0.018469  0.051932        0.234156 -0.008298
# mainroad_loc          1.000000   0.094764 -0.023735        0.101551  0.183071
# guestroom             0.094764   1.000000 -0.020243        0.133934  0.062764
# hotwater             -0.023735  -0.020243  1.000000       -0.119481  0.056666
# airconditioner        0.101551   0.133934 -0.119481        1.000000  0.139803
# parking               0.183071   0.062764  0.056666        0.139803  1.000000
# furnishingstatus     -0.165430  -0.131681 -0.032067       -0.128457 -0.162800
# h_price               0.331853   0.322570  0.051053        0.467519  0.324563
#
#                   furnishingstatus   h_price
# area                     -0.155728  0.572912
# no_bedrooms              -0.133968  0.369470
# no_bathrooms             -0.161125  0.453527
# total_stories            -0.101542  0.354870
# mainroad_loc             -0.165430  0.331853
# guestroom                -0.131681  0.322570
# hotwater                 -0.032067  0.051053
# airconditioner           -0.128457  0.467519
# parking                  -0.162800  0.324563
# furnishingstatus          1.000000 -0.354060
# h_price                  -0.354060  1.000000

# %% [markdown]
# - Price and area not very linear. There are moderate correlation.

# %%
HP_miss_out.head()
# Out:
#       area  no_bedrooms  no_bathrooms  total_stories  mainroad_loc  guestroom  \
# 15  6000.0          3.0           0.0            2.0           1.0        0.0
# 16  6600.0          3.0           1.0            2.0           1.0        1.0
# 17  8500.0          2.0           1.0            4.0           1.0        0.0
# 18  4600.0          2.0           1.0            2.0           1.0        1.0
# 19  6420.0          2.0           1.0            2.0           1.0        0.0
#
#     hotwater  airconditioner  parking  furnishingstatus    h_price
# 15       0.0             0.0      2.0               1.0  9100000.0
# 16       0.0             1.0      1.0               2.0  9100000.0
# 17       0.0             1.0      2.0               0.0  8960000.0
# 18       0.0             1.0      2.0               0.0  8890000.0
# 19       0.0             1.0      1.0               1.0  8855000.0

# %%
# Examine multicollinearity using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# the independent variables set
X_vif = HP_miss_out.drop(['h_price'], axis=1)

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X_vif.columns

# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i)
                          for i in range(len(X_vif.columns))]

print(vif_data)
# Out:
#             feature       VIF
# 0              area  9.662710
# 1       no_bedrooms  8.371096
# 2      no_bathrooms  1.595123
# 3     total_stories  7.045119
# 4      mainroad_loc  6.496517
# 5         guestroom  1.329238
# 6          hotwater  1.066743
# 7    airconditioner  1.746203
# 8           parking  1.913895
# 9  furnishingstatus  2.645623

# %% [markdown]
# - It seems that area, no_bedrooms, total_stories, and mainroad_loc are highly correlated

# %%
X_vif = HP_miss_out.drop(['h_price', 'no_bedrooms', 'total_stories', 'mainroad_loc'], axis=1)

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X_vif.columns

# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i)
                          for i in range(len(X_vif.columns))]

print(vif_data)
# Out:
#             feature       VIF
# 0              area  4.740717
# 1      no_bathrooms  1.406234
# 2         guestroom  1.322778
# 3          hotwater  1.054821
# 4    airconditioner  1.639921
# 5           parking  1.888405
# 6  furnishingstatus  2.339361

# %% [markdown]
# - after removing no of bedrooms, total stories and main road location correlation values look better now

# %% [markdown]
# ### Feature selection using selectK best method

# %%
# apply SelectKBest class to extract top 10 best features
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#               Specs          Score
# 0              area  172705.025438
# 8           parking     252.638749
# 2      no_bathrooms     227.441446
# 5         guestroom     224.755810
# 6          hotwater     200.336312
# 7    airconditioner     185.834255
# 9  furnishingstatus     129.899002
# 3     total_stories     118.837686
# 1       no_bedrooms      68.142844
# 4      mainroad_loc      34.609889

# %% [markdown]
# - It seems that number of bedrooms and main road location are not good predictor variable. However, total stories is also highly correlated with area.

# %%
# Linear regression
X_lin = HP_miss_out.drop(['h_price', 'no_bedrooms', 'total_stories', 'mainroad_loc'], axis=1)
y_lin = HP_miss_out['h_price']

# %%
X_lin.shape
# Out:
# (500, 7)

# %%
# splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
# fitting linear regression model
lm = LinearRegression()
lm.fit(X_train,y_train)
# regression coefficients
print('Coefficients: ', lm.coef_)
# Out:
# Coefficients:  [ 523183.88402183  225144.19421913  183319.94400125  498458.1471346
#   133097.80092469 -200751.0201337   497087.236279  ]

# %%
# fitting model into test data
y_pred = lm.predict(X_train)

# %%
# calculting rsquared value
r2 = r2_score(y_true=y_train,y_pred=y_pred)
print(r2)
# Out:
# 0.6122185184711437

# %%
# calculting adjusted rsquared value
N=X.shape[0]
p=5
x = (1-r2)
y = (N-1) / (N-p-1)
adj_rsquared = (1 - (x * y))
print("Adjusted-R2 : " , adj_rsquared)
# Out:
# Adjusted-R2 :  0.6082936046904873

# %%
# Checking mean value for residuala
residuals = y_train.values-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 1.4280279477437336e-10

# %% [markdown]
# - Mean value is close to 0 hence we are good to go

# %%
# scatter plot between predicted value and error
p = sns.scatterplot(y_pred, residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
p = sns.lineplot([0,2.6],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# checking if errors are normally distributed are not
sns.distplot((y_train-y_pred),bins=50)
# Out:
# C:\Users\sandy\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='h_price', ylabel='Density'>

# %%
predictions = lm.predict(X_test) # predicting test set

# %%
y_test.head()
# Out:
# 33     8120000.0
# 390    3500000.0
# 128    5810000.0
# 19     8855000.0
# 183    5110000.0
# Name: h_price, dtype: float64

# %%
predictions
# Out:
# array([6299688.72831512, 4472741.88996896, 4579472.62851454,
#        6504167.28531225, 5144332.97889532, 3103478.89700001,
#        4615794.83629225, 3915379.43407582, 6214533.15865725,
#        4467576.7692832 , 2536522.03632969, 3624552.02169755,
#        5648942.65922852, 4063588.80022617, 3793736.86725135,
#        5013929.00379806, 3122756.26095364, 2489537.91175084,
#        5051648.07804202, 3898695.40294738, 4727699.01769163,
#        3937724.74625416, 4377560.12664478, 3587555.8844294 ,
#        3778890.20493581, 3459694.347858  , 5940606.94119441,
#        4658548.51779944, 3918761.60454199, 3182447.6166144 ,
#        7043829.00721923, 2758964.49957476, 3193066.94327074,
#        4788326.31266246, 4926449.0459912 , 4974909.07060974,
#        5988215.2256264 , 3227303.83369079, 2917071.86681268,
#        3983225.79249417, 4487004.62449397, 3107178.72130188,
#        3488701.19127352, 5259401.05246544, 4302998.41432932,
#        4329273.44910259, 2783072.73159688, 3994001.02830039,
#        4732952.51908492, 4924985.6427637 , 3839069.09880253,
#        6011697.61294931, 5623476.67025664, 7306383.26132108,
#        3233844.63273871, 3103651.44975925, 5387744.95746398,
#        3315965.25460639, 5615158.82799011, 4349338.57467233,
#        4414207.755969  , 5783009.07997363, 4791978.30809632,
#        4599192.42293737, 3957310.76585871, 6371886.21390681,
#        3676072.69264586, 4072703.53485743, 6050621.95961313,
#        4924211.91615342, 4741275.33239024, 3090060.53195489,
#        2801897.7861314 , 2541945.07208575, 5145658.4442658 ,
#        2838275.69995754, 5544680.50340149, 3281993.11429999,
#        3905612.47653939, 5505959.33806751, 5182066.97436733,
#        4513292.64995627, 4554851.23938861, 6884753.12982327,
#        3226549.76109491, 4119780.10924269, 5809852.66796284,
#        6990494.19311005, 5842455.77481036, 4652472.46077828,
#        4738949.35790935, 4440955.78000735, 5091076.07457441,
#        3492679.5834925 , 3947053.30298263, 3663459.36682271,
#        3346938.65391857, 5358104.79802133, 3481817.79868061,
#        3319812.44052636, 4317050.95786677, 6055084.7039946 ,
#        5312976.47044984, 3048448.48139859, 3998068.57724331,
#        6612218.93433236, 6053367.12479635, 6210462.13382953,
#        3511670.63170972, 3048637.38042449, 6139967.6018668 ,
#        7255869.94291176, 3269436.0924982 , 6403477.66722171,
#        4059808.99692207, 5768291.15837339, 3668976.61350318,
#        5382043.00037977, 3103651.44975925, 4499296.36175309,
#        5822219.13500761, 3907776.72559751, 6628965.71106909,
#        3485076.87501419, 3834106.57969659])

# %%
# scatter plot between actaul and predicted value
plt.scatter(y_test,predictions)

# %%
# Calculating error
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 902532.8852364848
# MSE: 1310074299157.105
# RMSE: 1144584.7715032317

# %% [markdown]
# ## XGboost

# %%
# XGBoost
X = HP_miss_out.drop(['h_price', 'no_bedrooms', 'total_stories'], axis=1) # number of bedrooms and total stories are not good predictor
y = HP_miss_out['h_price']

# %%
# we will convert the dataset into an optimized data structure called Dmatrix that XGBoost supports
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)  #For splitting the test data

# %%
#We have to instantiate an XGBoost regressor object by calling the XGBRegressor() class from the XGBoost library with the hyper-parameters passed as arguments.
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
max_depth = 5, alpha = 10, n_estimators = 10)

# %%
#Fit the regressor to the training set and make predictions on the test set using the familiar .fit() and .predict() methods
xg_reg.fit(X_train,y_train)
preds = xg_reg.predict(X_test)
# Out:
# [13:04:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# we have to #Compute the rmse by invoking the mean_sqaured_error function from sklearn's
#metrics module.
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 2158399.225595

# %% [markdown]
# ## Random forest regression

# %%
# Importing library
from sklearn.ensemble import RandomForestRegressor

 # create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)

# fit the regressor with x and y data
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
# performing prediction
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([6284985.        , 4921280.        , 3863860.        ,
#        7647430.        , 4945640.        , 2300304.08333333,
#        4692327.5       , 4064060.        , 4954460.        ,
#        3688335.        , 2820790.        , 3441900.        ,
#        6879180.        , 3086370.        , 4089050.        ,
#        5318880.        , 3192955.5       , 2501100.        ,
#        4153660.        , 4450390.        , 4929260.        ,
#        3997840.        , 4654930.        , 4109899.5       ,
#        4759195.        , 3393740.        , 4271960.        ,
#        4765670.        , 4412100.        , 3777095.        ,
#        7903700.        , 3073558.83333333, 3037002.5       ,
#        4992493.33333333, 4583460.        , 4839625.        ,
#        4813620.        , 3113110.        , 2404430.        ,
#        4785900.        , 3815805.        , 2300304.08333333,
#        4234195.        , 4165420.        , 4062395.        ,
#        4681880.        , 2468573.33333333, 4741100.        ,
#        4327365.        , 4531800.        , 4365200.        ,
#        5451145.        , 5428920.        , 8099700.        ,
#        2859780.        , 2655730.        , 5920600.        ,
#        4318160.        , 5391190.        , 3682770.        ,
#        3846080.        , 5437075.        , 4178825.        ,
#        5008990.        , 4062800.        , 7237136.66666667,
#        4101300.        , 4178930.        , 5663280.        ,
#        4495295.        , 4759020.        , 2661330.        ,
#        3102879.5       , 2571450.        , 6408080.        ,
#        2163408.33333333, 4934790.        , 3262770.        ,
#        4453330.        , 5169710.        , 3886935.5       ,
#        4277490.        , 4628890.        , 7231140.        ,
#        3370710.        , 4196290.        , 4796353.33333333,
#        7368130.        , 4791150.        , 4620805.        ,
#        4324413.33333333, 4739070.        , 4543910.        ,
#        3749130.        , 3985356.66666667, 4323340.        ,
#        3351197.5       , 5868380.        , 3287900.        ,
#        4216800.        , 4417560.        , 5634790.        ,
#        4547620.        , 3301200.        , 2918930.        ,
#        7447486.66666667, 6016150.        , 5715395.        ,
#        3761940.        , 2955330.        , 5546450.        ,
#        7306833.33333333, 3213070.        , 6449940.        ,
#        4316795.        , 5008290.        , 3613330.        ,
#        4154937.5       , 2655730.        , 4237817.5       ,
#        5710856.66666667, 4479230.        , 7275986.66666667,
#        3506160.        , 4232900.        ])

# %%
# calculating error
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 899790.7560000002
# MSE: 1321354311394.4067
# RMSE: 1149501.766590381

# %% [markdown]
# ## Support vector regression

# %%
# Importing SVR library and creating model
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = regressor.predict(X_test) # prediciting y

# %%
# Calculating error
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 1189061.8302153759
# MSE: 2634614177409.064
# RMSE: 1623149.4624368588

# %% [markdown]
# ### Conclusion
# Here, we performed 4 different models to check which model seems to give a better accuracy or least error. Overall, number of bedrooms and location from the main road do not seem to be a good predictor of a house price. Hence, they were dropped from all models. Linear regression seems to be the best model as it has the lowest error, but linear relationship between price and area is not very linear. Random forest model may be the best model in this scenario. We can also perform cross validation and parameter optimization to improve the model accuracy.

# %% [markdown]
# **Note**: This a basic model using correct approach. We can still perform more models, parameter optimization and cross validation to identify the best model for the project.
